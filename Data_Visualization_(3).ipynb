# %% [markdown]
# <a href="https://colab.research.google.com/github/thejapamarthy/Python-strings-and-if-condition/blob/main/Data_Visualization_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/afeld/python-public-policy/blob/main/hw_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# #Data visualization
#
#
#
# 1. Complete the **Coding** exercise below.
# 1. **Tutorial:** Go the first third of [Time Series Analysis with Pandas](https://www.dataquest.io/blog/tutorial-time-series-analysis-with-pandas/), up until the "Visualizing time series data" section.

# %%
# %pip install --upgrade --quiet plotly

# %% [markdown]
# ### Step 1
#
# Load the request per capita dataset from https://nyu.box.com/shared/static/m8zlqkoore2qq1n84a8as3r3o5hxwwth.csv as `requests_by_cd` and display it.

# %%
# your code here
# reading the dataset
import pandas as pd
requests_by_cd = pd.read_csv('https://nyu.box.com/shared/static/m8zlqkoore2qq1n84a8as3r3o5hxwwth.csv')
requests_by_cd.head() # getting first 5 values
# Out:
#    borocd    Borough  ... count_of_311_requests  request_per_capita
# 0     112  Manhattan  ...                 81403            0.428392
# 1     405     Queens  ...                 71506            0.422637
# 2     412     Queens  ...                 70362            0.311448
# 3     301   Brooklyn  ...                 68104            0.393476
# 4     303   Brooklyn  ...                 66360            0.433768
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Step 2
#
# Make a [histogram](https://plotly.com/python/histograms/) of the requests per capita.

# %%
# your code here
import pandas as pd
import plotly.express as px
#requests_by_cd['borocd']
#fig = [px.histogram(requests_by_cd, x='2010 Population')
#fig.show()
requests_by_cd = pd.read_csv('https://nyu.box.com/shared/static/m8zlqkoore2qq1n84a8as3r3o5hxwwth.csv')
#df=pd.read_csv('https://nyu.box.com/shared/static/m8zlqkoore2qq1n84a8as3r3o5hxwwth.csv',low_memory=False)
fig = px.histogram(requests_by_cd,
                   x='request_per_capita',
                   title='Volume of 311 requests, 2018-2019',
                   labels={'request_per_capita': '311 requests per capita'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="d5637eee-f1bd-4207-8fbe-65bf3f6dd4db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5637eee-f1bd-4207-8fbe-65bf3f6dd4db")) {                    Plotly.newPlot(                        "d5637eee-f1bd-4207-8fbe-65bf3f6dd4db",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "311 requests per capita=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.4283917482370277, 0.4226372717063656, 0.311447908321124, 0.3934759623995424, 0.4337680164722032, 0.3706672887412094, 0.25725882742951395, 0.3381101828361473, 0.4171509345060468, 0.3161979016770885, 0.3791577564218174, 0.3559851615794453, 0.4001550766049711, 0.2817100075952114, 0.3797246662991829, 0.2863573939647813, 0.35241296014283463, 0.2901456745484419, 0.40421216848673946, 0.3148085768356841, 0.4322822602248473, 0.4399382069357388, 0.3257426856465948, 0.3053116191669277, 0.30417142607468994, 0.3979623517108402, 0.2425515461224149, 0.22111208892119916, 0.2672404787054986, 0.4423040244135037, 0.35335887734856336, 0.4555270616817384, 0.43335805504475305, 0.4062688021087013, 0.30439459709249034, 0.35628397448113763, 0.2287149717909265, 0.3759891520170469, 0.17428155692979266, 0.3312402854316801, 0.7251369187002884, 0.4075942054745823, 0.2874990097441179, 0.3112897526501767, 0.19409842524247092, 0.2731161538972689, 0.3224877372678928, 0.2802346454123043, 0.38957342556564345, 0.26909576719137673, 0.2639635408512933, 0.20928929209429406, 0.3728341816905293, 0.33240042559097005, 0.2989606216597265, 0.2331599812815102, 0.212480101267765, 0.3486339335498049, 0.3835700340695937], "xaxis": "x", "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.888888888 ...

# %% [markdown]
# ## In-class exercise 2
#
# Take [the scatterplot example from the lecture](https://colab.research.google.com/github/afeld/python-public-policy/blob/main/lecture_3.ipynb#scrollTo=L1smfBSEc5x9) and [add a trendline](https://plotly.com/python/linear-fits/).

# %%
# your code here
fig = px.scatter(requests_by_cd,
                 x='2010 Population',
                 y='count_of_311_requests',
                 hover_data=['borocd', 'CD Name'],color="Borough",
                 trendline='ols')

fig.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="1a07a48a-d6ad-4475-b9bf-f162a27b6033" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a07a48a-d6ad-4475-b9bf-f162a27b6033")) {                    Plotly.newPlot(                        "1a07a48a-d6ad-4475-b9bf-f162a27b6033",                        [{"customdata": [[112, "Washington Heights, Inwood"], [103, "Lower East Side, Chinatown"], [110, "Central Harlem"], [107, "West Side, Upper West Side"], [109, "Manhattanville, Hamilton Heights"], [104, "Chelsea, Clinton"], [108, "Upper East Side"], [105, "Midtown Business District"], [102, "Greenwich Village, Soho"], [111, "East Harlem"], [106, "Stuyvesant Town, Turtle Bay"], [101, "Battery Park City, Tribeca"]], "hovertemplate": "Borough=Manhattan<br>2010 Population=%{x}<br>count_of_311_requests=%{y}<br>borocd=%{customdata[0]}<br>CD Name=%{customdata[1]}<extra></extra>", "legendgroup": "Manhattan", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Manhattan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [190020, 163277, 115723, 209084, 110193, 103245, 219920, 51673, 90016, 120511, 142745, 60978], "xaxis": "x", "y": [81403, 51401, 50025, 46231, 39260, 38819, 38328, 37470, 36690, 32429, 29875, 21259], "yaxis": "y"}, {"hovertemplate": "<b>OLS trendline</b><br>count_of_311_requests = 0.140334 * 2010 Population + 23485.7<br>R<sup>2</sup>=0.263608<br><br>Borough=Manhattan<br>2010 Population=%{x}<br>count_of_311_requests=%{y} <b>(trend)</b><extra></extra>", "legendgroup": "Manhattan", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Manhattan", "showlegend": false, "type": "scatter", "x": [51673, 60978, 90016, 103245, 110193, 115723, 120511, 142745, 163277, 190020, 209084, 219920], "xaxis": "x", "y": [30737.22850603901, 32043.038871360637, 36118.06535048041, 37974.547384101024, 38949.58987934602, 39725.63838232599, 40397.55885832384, 43517.75097681509, 46399.09417088104, 50152.05350455072, 52827.38599294315, 54348.04812283301], "yaxis": "y"}, {"customdata": [[405, "Ridgewood, Glendale, Maspeth"], [412, "Jamaica, St. Albans, Hollis"], [407, "Flushing, Bay Terrace"], [401, "Astoria, Long Island City"], [409, "Woodhaven, Richmond Hill"], [413, "Queens Village, Rosedale"], [408, "Fresh Meadows, Briarwood"], [410, "Ozone Park, Howard Beach"], [403, "Jackson Heights, North Corona"], [402, "Sunnyside, Woodside"], [404, "Elmhurst, South Corona"], [411, "Bayside, Douglaston, Little Neck"], [414, "The Rockaways, Broad Channel"], [406, "Forest Hills, Rego Park"]], "hovertemplate": "Borough=Queens<br>2010 Population=%{x}<br>count_of_311_requests=%{y}<br>borocd=%{customdata[0]}<br>CD Name=%{customdata[1]}<extra></extra>", "legendgroup": "Queens", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Queens", "orientation": "v", "showlegend": true, "type": "scatter", "x": [169190, 225919, 247354, 191105, 143317, 188593, 151107, 122396, 171576, 113200, 172598, 116431, 114978, 113257], "xaxis": "x", "y": [71506, 70362, 63634, 60427, 54421, 54005, 49222, 48709, 39242, 35238, 33501, 32628, 30350, 26407], "yaxis": "y"}, {"hovertemplate": "<b>OLS trendline</b><br>count_of_311_requests = 0.258425 * 2010 Population + 6465.48<br>R<sup>2</sup>=0.539986<br><br>Borough=Queens<br>2010 Population=%{x}<br>count_of_311_requests=%{y} <b>(trend)</b><extra></extra>", "legendgroup": "Queens", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines", "name": "Queens", "showlegend": false, "type": "scatter", "x": [113200, 113257, 114978, 116431, 122396, 143317, 151107, 169190, 171576, 172598, 188593, 191105, 225919, 247354], "xaxis": "x", "y": [35719.16084939768, 35733.89106016842, 36178.64005554438, 36554.13121782287, ...

# %% [markdown]
# ## Coding
#
# We are going to look at the population count of different community districts over time. First, let's make sure Plotly is up-to-date to avoid issues later.

# %%
# %pip install --upgrade --quiet plotly
import plotly.express as px

# %% [markdown]
# ### Step 1
#
# Read the data from the [New York City Population By Community Districts](https://data.cityofnewyork.us/City-Government/New-York-City-Population-By-Community-Districts/xi7c-iiu2/data) data set into a DataFrame called `pop_by_cd`, then display it. To get the URL:
#
# 1. Visit the page linked above.
# 1. Click `Export`.
# 1. Right-click `CSV`.
# 1. Click `Copy Link Address` (or `Location`, depending on your browser).

# %%
# your code here
import pandas as pd
pop_by_cd=pd.read_csv('https://data.cityofnewyork.us/api/views/xi7c-iiu2/rows.csv?accessType=DOWNLOAD', low_memory=False)
print(pop_by_cd)
pop_by_cd.head()
# Out:
#           Borough  CD Number  ... 2000 Population  2010 Population
# 0           Bronx          1  ...           82159            91497
# 1           Bronx          2  ...           46824            52246
# 2           Bronx          3  ...           68574            79762
# 3           Bronx          4  ...          139563           146441
# 4           Bronx          5  ...          128313           128200
# 5           Bronx          6  ...           75688            83268
# 6           Bronx          7  ...          141411           139286
# 7           Bronx          8  ...          101332           101731
# 8           Bronx          9  ...          167859           172298
# 9           Bronx         10  ...          115948           120392
# 10          Bronx         11  ...          110706           113232
# 11          Bronx         12  ...          149077           152344
# 12       Brooklyn          1  ...          160338           173083
# 13       Brooklyn          2  ...           98620            99617
# 14       Brooklyn          3  ...          143867           152985
# 15       Brooklyn          4  ...          104358           112634
# 16       Brooklyn          5  ...          173198           182896
# 17       Brooklyn          6  ...          104054           104709
# 18       Brooklyn          7  ...          120063           126230
# 19       Brooklyn          8  ...           96076            96317
# 20       Brooklyn          9  ...          104014            98429
# 21       Brooklyn         10  ...          122542           124491
# 22       Brooklyn         11  ...          172129           181981
# 23       Brooklyn         12  ...          185046           191382
# 24       Brooklyn         13  ...          106120           104278
# 25       Brooklyn         14  ...          168806           160664
# 26       Brooklyn         15  ...          160319           159650
# 27       Brooklyn         16  ...           85343            86468
# 28       Brooklyn         17  ...          165753           155252
# 29       Brooklyn         18  ...          194653           193543
# 30      Manhattan          1  ...           34420            60978
# 31      Manhattan          2  ...           93119            90016
# 32      Manhattan          3  ...          164407           163277
# 33      Manhattan          4  ...           87479           103245
# 34      Manhattan          5  ...           44028            51673
# 35      Manhattan          6  ...          136152           142745
# 36      Manhattan          7  ...          207699           209084
# 37      Manhattan          8  ...          217063           219920
# 38      Manhattan          9  ...          111724           110193
# 39      Manhattan         10  ...          107109           115723
# 40      Manhattan         11  ...          117743           120511
# 41      Manhattan         12  ...          208414           190020
# 42         Queens          1  ...          211220           191105
# 43         Queens          2  ...          109920           113200
# 44         Queens          3  ...          169083           171576
# 45         Queens          4  ...          167005           172598
# 46         Queens          5  ...          165911           169190
# 47         Queens          6  ...          115967           113257
# 48         Queens          7  ...          242952           247354
# 49         Queens          8  ...          146594           151107
# 50         Queens          9  ...          141608           143317
# 51         Queens         10  ...          127274           122396
# 52         Queens         11  ...          116404           116431
# 53         Queens         12  ...          223602           225919
# 54         Queens         13  ...          196284           188593
# 55         Queens         14  ...          106686           114978
# 56  Staten Island          1  ...          162609           175756
# 57  Staten Island          2  ...          127071           132003
# 58  Staten Island          3  ...          152908           160209
#
# [59 rows x 8 columns]
#   Borough  CD Number  ... 2000 Population  2010 Population
# 0   Bronx          1  ...           82159            91497
# 1   Bronx          2  ...           46824            52246
# 2   Bronx          3  ...           68574            79762
# 3   Bronx          4  ...          139563           146441
# 4   Bronx          5  ...          128313           128200
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Step 2
#
# Prepare the data. Use the following code to [reshape](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html) the DataFrame to have one row per community district per Census year.

# %%
# turn the population columns into rows
populations = pd.melt(pop_by_cd, id_vars=['Borough', 'CD Number', 'CD Name'], var_name='year', value_name='population')

# turn the years into numbers
populations.year = populations.year.str.replace(' Population', '').astype(int)

populations
# Out:
#            Borough  CD Number  ...  year  population
# 0            Bronx          1  ...  1970      138557
# 1            Bronx          2  ...  1970       99493
# 2            Bronx          3  ...  1970      150636
# 3            Bronx          4  ...  1970      144207
# 4            Bronx          5  ...  1970      121807
# ..             ...        ...  ...   ...         ...
# 290         Queens         13  ...  2010      188593
# 291         Queens         14  ...  2010      114978
# 292  Staten Island          1  ...  2010      175756
# 293  Staten Island          2  ...  2010      132003
# 294  Staten Island          3  ...  2010      160209
#
# [295 rows x 5 columns]

# %% [markdown]
# ### Step 3
#
# Create a new `manhattan` DataFrame that has only the populations for that borough.

# %%
# your code here
#creating a new dataframe with pop values from Manhattan
manhattan= populations.loc[populations["Borough"]=='Manhattan']
print(manhattan)
# Out:
#        Borough  CD Number                           CD Name  year  population
# 30   Manhattan          1        Battery Park City, Tribeca  1970        7706
# 31   Manhattan          2           Greenwich Village, Soho  1970       84337
# 32   Manhattan          3        Lower East Side, Chinatown  1970      181845
# 33   Manhattan          4                  Chelsea, Clinton  1970       83601
# 34   Manhattan          5         Midtown Business District  1970       31076
# 35   Manhattan          6       Stuyvesant Town, Turtle Bay  1970      122465
# 36   Manhattan          7        West Side, Upper West Side  1970      212422
# 37   Manhattan          8                   Upper East Side  1970      200851
# 38   Manhattan          9  Manhattanville, Hamilton Heights  1970      113606
# 39   Manhattan         10                    Central Harlem  1970      159267
# 40   Manhattan         11                       East Harlem  1970      154662
# 41   Manhattan         12        Washington Heights, Inwood  1970      180561
# 89   Manhattan          1        Battery Park City, Tribeca  1980       15918
# 90   Manhattan          2           Greenwich Village, Soho  1980       87069
# 91   Manhattan          3        Lower East Side, Chinatown  1980      154848
# 92   Manhattan          4                  Chelsea, Clinton  1980       82164
# 93   Manhattan          5         Midtown Business District  1980       39544
# 94   Manhattan          6       Stuyvesant Town, Turtle Bay  1980      127554
# 95   Manhattan          7        West Side, Upper West Side  1980      206669
# 96   Manhattan          8                   Upper East Side  1980      204305
# 97   Manhattan          9  Manhattanville, Hamilton Heights  1980      103038
# 98   Manhattan         10                    Central Harlem  1980      105641
# 99   Manhattan         11                       East Harlem  1980      114569
# 100  Manhattan         12        Washington Heights, Inwood  1980      179941
# 148  Manhattan          1        Battery Park City, Tribeca  1990       25366
# 149  Manhattan          2           Greenwich Village, Soho  1990       94105
# 150  Manhattan          3        Lower East Side, Chinatown  1990      161617
# 151  Manhattan          4                  Chelsea, Clinton  1990       84431
# 152  Manhattan          5         Midtown Business District  1990       43507
# 153  Manhattan          6       Stuyvesant Town, Turtle Bay  1990      133748
# 154  Manhattan          7        West Side, Upper West Side  1990      210993
# 155  Manhattan          8                   Upper East Side  1990      210880
# 156  Manhattan          9  Manhattanville, Hamilton Heights  1990      106978
# 157  Manhattan         10                    Central Harlem  1990       99519
# 158  Manhattan         11                       East Harlem  1990      110508
# 159  Manhattan         12        Washington Heights, Inwood  1990      198192
# 207  Manhattan          1        Battery Park City, Tribeca  2000       34420
# 208  Manhattan          2           Greenwich Village, Soho  2000       93119
# 209  Manhattan          3        Lower East Side, Chinatown  2000      164407
# 210  Manhattan          4                  Chelsea, Clinton  2000       87479
# 211  Manhattan          5         Midtown Business District  2000       44028
# 212  Manhattan          6       Stuyvesant Town, Turtle Bay  2000      136152
# 213  Manhattan          7        West Side, Upper West Side  2000      207699
# 214  Manhattan          8                   Upper East Side  2000      217063
# 215  Manhattan          9  Manhattanville, Hamilton Heights  2000      111724
# 216  Manhattan         10                    Central Harlem  2000      107109
# 217  Manhattan         11                       East Harlem  2000      117743
# 218  Manhattan         12        Washington Heights, Inwood  2000      208414
# 266  Manhattan          1        Battery Park City, Tribeca  2010       60978
# 267  Manhattan          2           Greenwich Village, Soho  2010       90016
# 268  Manhattan          3        Lower East Side, Chinatown  2010      163277
# 269  Manhattan          4                  Chelsea, Clinton  2010      103245
# 270  Manhattan          5         Midtown Business District  2010       51673
# 271  Manhattan          6       Stuyvesant Town, Turtle Bay  2010      142745
# 272  Manhattan          7        West Side, Upper West Side  2010      209084
# 273  Manhattan          8                   Upper East Side  2010      219920
# 274  Manhattan          9  Manhattanville, Hamilton Heights  2010      110193
# 275  Manhattan         10                    Central Harlem  2010      115723
# 276  Manhattan         11                       East Harlem  2010      120511
# 277  Manhattan         12        Washington Heights, Inwood  2010      190020

# %% [markdown]
# ### Step 4
#
# Create a line chart of the population over time for each community district in Manhattan. There should be one line for each.
#
# See the Plotly [Line Plot with column encoding color](https://plotly.com/python/line-charts/#line-plot-with-column-encoding-color) examples.

# %%
# your code here
import plotly.express as px
fig = px.line(manhattan, x="year", y="population", color='CD Name')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="a3493432-1fca-4cd6-8c4e-3ffad0f1f447" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3493432-1fca-4cd6-8c4e-3ffad0f1f447")) {                    Plotly.newPlot(                        "a3493432-1fca-4cd6-8c4e-3ffad0f1f447",                        [{"hovertemplate": "CD Name=Battery Park City, Tribeca<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "Battery Park City, Tribeca", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Battery Park City, Tribeca", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1970, 1980, 1990, 2000, 2010], "xaxis": "x", "y": [7706, 15918, 25366, 34420, 60978], "yaxis": "y"}, {"hovertemplate": "CD Name=Greenwich Village, Soho<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "Greenwich Village, Soho", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Greenwich Village, Soho", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1970, 1980, 1990, 2000, 2010], "xaxis": "x", "y": [84337, 87069, 94105, 93119, 90016], "yaxis": "y"}, {"hovertemplate": "CD Name=Lower East Side, Chinatown<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "Lower East Side, Chinatown", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Lower East Side, Chinatown", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1970, 1980, 1990, 2000, 2010], "xaxis": "x", "y": [181845, 154848, 161617, 164407, 163277], "yaxis": "y"}, {"hovertemplate": "CD Name=Chelsea, Clinton<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "Chelsea, Clinton", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Chelsea, Clinton", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1970, 1980, 1990, 2000, 2010], "xaxis": "x", "y": [83601, 82164, 84431, 87479, 103245], "yaxis": "y"}, {"hovertemplate": "CD Name=Midtown Business District<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "Midtown Business District", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Midtown Business District", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1970, 1980, 1990, 2000, 2010], "xaxis": "x", "y": [31076, 39544, 43507, 44028, 51673], "yaxis": "y"}, {"hovertemplate": "CD Name=Stuyvesant Town, Turtle Bay<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "Stuyvesant Town, Turtle Bay", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "Stuyvesant Town, Turtle Bay", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1970, 1980, 1990, 2000, 2010], "xaxis": "x", "y": [122465, 127554, 133748, 136152, 142745], "yaxis": "y"}, {"hovertemplate": "CD Name=West Side, Upper West Side<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "West Side, Upper West Side", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "West Side, Upper West Side", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1970, 1980, 1990, 2000, 2010], "xaxis": "x", "y": [212422, 206669, 210993, 207699, 209084], "yaxis": "y"}, {"hovertemplate": "CD Name=Upper East Side<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "Upper East Side", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "lines", "name": "Upper East Side", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1970, 1980, 1990, 2000, 2010], "xaxis": "x", "y": [200851, 204305, 210880, 217063, 219920], "yaxis": "y"}, {"hovertemplate": "CD Name=Manhattanville, Hamilton Heights<br>year=%{x}<br>population=%{y}<extra></extra>", "legendgroup": "Manhattanville, Hamilton Heights", "line":  ...

# %% [markdown]
# ### Step 5
#
# We are going to do some mapping using the `pop_by_cd` DataFrame from before. To do so, we need `borocd`s. Create that column with the values filled in. (See [Lecture 2](https://colab.research.google.com/github/afeld/python-public-policy/blob/main/lecture_2.ipynb#scrollTo=Pq24B8pRC_FM).)

# %%
# your code here
def recode_borocd_pop(row):
  if row.Borough == 'Manhattan':
    return str(100 + row['CD Number'])
  elif row.Borough == 'Bronx':
    return str(200 + row['CD Number'])
  elif row.Borough == 'Brooklyn':
    return str(300 + row['CD Number'])
  elif row.Borough == 'Queens':
    return str(400 + row['CD Number'])
  elif row.Borough == 'Staten Island':
    return str(500 + row['CD Number'])
  else:
    return 'Invalid BoroCD'
pop_by_cd['borocd'] = pop_by_cd.apply(recode_borocd_pop, axis=1)
pop_by_cd
# Out:
#           Borough  CD Number  ... 2010 Population  borocd
# 0           Bronx          1  ...           91497     201
# 1           Bronx          2  ...           52246     202
# 2           Bronx          3  ...           79762     203
# 3           Bronx          4  ...          146441     204
# 4           Bronx          5  ...          128200     205
# 5           Bronx          6  ...           83268     206
# 6           Bronx          7  ...          139286     207
# 7           Bronx          8  ...          101731     208
# 8           Bronx          9  ...          172298     209
# 9           Bronx         10  ...          120392     210
# 10          Bronx         11  ...          113232     211
# 11          Bronx         12  ...          152344     212
# 12       Brooklyn          1  ...          173083     301
# 13       Brooklyn          2  ...           99617     302
# 14       Brooklyn          3  ...          152985     303
# 15       Brooklyn          4  ...          112634     304
# 16       Brooklyn          5  ...          182896     305
# 17       Brooklyn          6  ...          104709     306
# 18       Brooklyn          7  ...          126230     307
# 19       Brooklyn          8  ...           96317     308
# 20       Brooklyn          9  ...           98429     309
# 21       Brooklyn         10  ...          124491     310
# 22       Brooklyn         11  ...          181981     311
# 23       Brooklyn         12  ...          191382     312
# 24       Brooklyn         13  ...          104278     313
# 25       Brooklyn         14  ...          160664     314
# 26       Brooklyn         15  ...          159650     315
# 27       Brooklyn         16  ...           86468     316
# 28       Brooklyn         17  ...          155252     317
# 29       Brooklyn         18  ...          193543     318
# 30      Manhattan          1  ...           60978     101
# 31      Manhattan          2  ...           90016     102
# 32      Manhattan          3  ...          163277     103
# 33      Manhattan          4  ...          103245     104
# 34      Manhattan          5  ...           51673     105
# 35      Manhattan          6  ...          142745     106
# 36      Manhattan          7  ...          209084     107
# 37      Manhattan          8  ...          219920     108
# 38      Manhattan          9  ...          110193     109
# 39      Manhattan         10  ...          115723     110
# 40      Manhattan         11  ...          120511     111
# 41      Manhattan         12  ...          190020     112
# 42         Queens          1  ...          191105     401
# 43         Queens          2  ...          113200     402
# 44         Queens          3  ...          171576     403
# 45         Queens          4  ...          172598     404
# 46         Queens          5  ...          169190     405
# 47         Queens          6  ...          113257     406
# 48         Queens          7  ...          247354     407
# 49         Queens          8  ...          151107     408
# 50         Queens          9  ...          143317     409
# 51         Queens         10  ...          122396     410
# 52         Queens         11  ...          116431     411
# 53         Queens         12  ...          225919     412
# 54         Queens         13  ...          188593     413
# 55         Queens         14  ...          114978     414
# 56  Staten Island          1  ...          175756     501
# 57  Staten Island          2  ...          132003     502
# 58  Staten Island          3  ...          160209     503
#
# [59 rows x 9 columns]

# %% [markdown]
# ### Step 6
#
# Create a `change` column on the `pop_by_cd` DataFrame with the difference between the 2000 and 2010 population counts, then display the DataFrame.

# %%
# your code here
pop_by_cd['change']= pop_by_cd['2010 Population']-pop_by_cd['2000 Population']
pop_by_cd
# Out:
#           Borough  CD Number  ... borocd  change
# 0           Bronx          1  ...    201    9338
# 1           Bronx          2  ...    202    5422
# 2           Bronx          3  ...    203   11188
# 3           Bronx          4  ...    204    6878
# 4           Bronx          5  ...    205    -113
# 5           Bronx          6  ...    206    7580
# 6           Bronx          7  ...    207   -2125
# 7           Bronx          8  ...    208     399
# 8           Bronx          9  ...    209    4439
# 9           Bronx         10  ...    210    4444
# 10          Bronx         11  ...    211    2526
# 11          Bronx         12  ...    212    3267
# 12       Brooklyn          1  ...    301   12745
# 13       Brooklyn          2  ...    302     997
# 14       Brooklyn          3  ...    303    9118
# 15       Brooklyn          4  ...    304    8276
# 16       Brooklyn          5  ...    305    9698
# 17       Brooklyn          6  ...    306     655
# 18       Brooklyn          7  ...    307    6167
# 19       Brooklyn          8  ...    308     241
# 20       Brooklyn          9  ...    309   -5585
# 21       Brooklyn         10  ...    310    1949
# 22       Brooklyn         11  ...    311    9852
# 23       Brooklyn         12  ...    312    6336
# 24       Brooklyn         13  ...    313   -1842
# 25       Brooklyn         14  ...    314   -8142
# 26       Brooklyn         15  ...    315    -669
# 27       Brooklyn         16  ...    316    1125
# 28       Brooklyn         17  ...    317  -10501
# 29       Brooklyn         18  ...    318   -1110
# 30      Manhattan          1  ...    101   26558
# 31      Manhattan          2  ...    102   -3103
# 32      Manhattan          3  ...    103   -1130
# 33      Manhattan          4  ...    104   15766
# 34      Manhattan          5  ...    105    7645
# 35      Manhattan          6  ...    106    6593
# 36      Manhattan          7  ...    107    1385
# 37      Manhattan          8  ...    108    2857
# 38      Manhattan          9  ...    109   -1531
# 39      Manhattan         10  ...    110    8614
# 40      Manhattan         11  ...    111    2768
# 41      Manhattan         12  ...    112  -18394
# 42         Queens          1  ...    401  -20115
# 43         Queens          2  ...    402    3280
# 44         Queens          3  ...    403    2493
# 45         Queens          4  ...    404    5593
# 46         Queens          5  ...    405    3279
# 47         Queens          6  ...    406   -2710
# 48         Queens          7  ...    407    4402
# 49         Queens          8  ...    408    4513
# 50         Queens          9  ...    409    1709
# 51         Queens         10  ...    410   -4878
# 52         Queens         11  ...    411      27
# 53         Queens         12  ...    412    2317
# 54         Queens         13  ...    413   -7691
# 55         Queens         14  ...    414    8292
# 56  Staten Island          1  ...    501   13147
# 57  Staten Island          2  ...    502    4932
# 58  Staten Island          3  ...    503    7301
#
# [59 rows x 10 columns]

# %% [markdown]
# ### Step 7
#
# Let make a [choropleth map](https://www.data-to-viz.com/graph/choropleth.html) showing the population change for each community district that we just calculated. Adapt [the `.choropleth_mapbox()` example in Lecture 3](https://colab.research.google.com/github/afeld/python-public-policy/blob/main/lecture_3.ipynb#scrollTo=5lLS8zmn6oHP).
#
# If you get an error about `choropleth_mapbox() got an unexpected keyword argument 'featureidkey'`, go back and do the `Setup` above.

# %%
# your code here
import json
geojson = 'https://data.cityofnewyork.us/api/geospatial/yfnk-k7r4?method=export&format=GeoJSON'

fig = px.choropleth_mapbox(pop_by_cd,
                           geojson=geojson,
                           locations='borocd',
                           featureidkey='properties.boro_cd',
                           color='change',
                           hover_data=['CD Name'],
                           center = {'lat': 40.73, 'lon': -73.98},
                           zoom=9,
                           mapbox_style='carto-positron')
#fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(height=700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="ebaac75e-6389-4364-88d7-76f13c0db92d" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebaac75e-6389-4364-88d7-76f13c0db92d")) {                    Plotly.newPlot(                        "ebaac75e-6389-4364-88d7-76f13c0db92d",                        [{"coloraxis": "coloraxis", "customdata": [["Melrose, Mott Haven, Port Morris"], ["Hunts Point, Longwood"], ["Morrisania, Crotona Park East"], ["Highbridge, Concourse Village"], ["University Hts., Fordham, Mt. Hope"], ["East Tremont, Belmont"], ["Bedford Park, Norwood, Fordham"], ["Riverdale, Kingsbridge, Marble Hill"], ["Soundview, Parkchester"], ["Throgs Nk., Co-op City, Pelham Bay"], ["Pelham Pkwy, Morris Park, Laconia"], ["Wakefield, Williamsbridge"], ["Williamsburg, Greenpoint"], ["Brooklyn Heights, Fort Greene"], ["Bedford Stuyvesant"], ["Bushwick"], ["East New York, Starrett City"], ["Park Slope, Carroll Gardens"], ["Sunset Park, Windsor Terrace"], ["Crown Heights North"], ["Crown Heights South, Wingate"], ["Bay Ridge, Dyker Heights"], ["Bensonhurst, Bath Beach "], ["Borough Park, Ocean Parkway"], ["Coney Island, Brighton Beach"], ["Flatbush, Midwood"], ["Sheepshead Bay, Gerritsen Beach"], ["Brownsville, Ocean Hill"], ["East Flatbush, Rugby, Farragut"], ["Canarsie, Flatlands"], ["Battery Park City, Tribeca"], ["Greenwich Village, Soho"], ["Lower East Side, Chinatown"], ["Chelsea, Clinton"], ["Midtown Business District"], ["Stuyvesant Town, Turtle Bay"], ["West Side, Upper West Side"], ["Upper East Side"], ["Manhattanville, Hamilton Heights"], ["Central Harlem"], ["East Harlem"], ["Washington Heights, Inwood"], ["Astoria, Long Island City"], ["Sunnyside, Woodside"], ["Jackson Heights, North Corona"], ["Elmhurst, South Corona"], ["Ridgewood, Glendale, Maspeth"], ["Forest Hills, Rego Park"], ["Flushing, Bay Terrace"], ["Fresh Meadows, Briarwood"], ["Woodhaven, Richmond Hill"], ["Ozone Park, Howard Beach"], ["Bayside, Douglaston, Little Neck"], ["Jamaica, St. Albans, Hollis"], ["Queens Village, Rosedale"], ["The Rockaways, Broad Channel"], ["Stapleton, Port Richmond"], ["New Springville, South Beach"], ["Tottenville, Woodrow, Great Kills"]], "featureidkey": "properties.boro_cd", "geojson": "https://data.cityofnewyork.us/api/geospatial/yfnk-k7r4?method=export&format=GeoJSON", "hovertemplate": "borocd=%{location}<br>CD Name=%{customdata[0]}<br>change=%{z}<extra></extra>", "locations": ["201", "202", "203", "204", "205", "206", "207", "208", "209", "210", "211", "212", "301", "302", "303", "304", "305", "306", "307", "308", "309", "310", "311", "312", "313", "314", "315", "316", "317", "318", "101", "102", "103", "104", "105", "106", "107", "108", "109", "110", "111", "112", "401", "402", "403", "404", "405", "406", "407", "408", "409", "410", "411", "412", "413", "414", "501", "502", "503"], "name": "", "subplot": "mapbox", "type": "choroplethmapbox", "z": [9338, 5422, 11188, 6878, -113, 7580, -2125, 399, 4439, 4444, 2526, 3267, 12745, 997, 9118, 8276, 9698, 655, 6167, 241, -5585, 1949, 9852, 6336, -1842, -8142, -669, 1125, -10501, -1110, 26558, -3103, -1130, 15766, 7645, 6593, 1385, 2857, -1531, 8614, 2768, -18394, -20115, 3280, 2493, 5593, 3279, -2710, 4402, 4513, 1709, -4878, 27, 2317, -7691, 8292, 13147, 4932, 7301]}],                        {"coloraxis": {"colorbar": {"title": {"text": "change"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "height": 700, "legend": {"tracegroupgap": 0}, "mapbox": {"center": {"lat": 4 ...

# %% [markdown]
# ### Step 8
#
# ***Analysis: Washington Heights and Inwood (the tall skinny community district at the top of Manhattan) are "up and coming" neighborhoods. Why might you guess the population decreased?***
#
# YOUR ANSWER HERE
# Could be due to migration/ under reporting
#
# Then, read the first three paragraphs of the `Demographics` section of [An Economic Snapshot of Washington Heights and Inwood from June 2015](https://www.osc.state.ny.us/osdc/rpt2-2016.pdf#page=2).

# %% [markdown]
# ## Tutorials
#
# 1. Read the [Data Design Standards](https://xdgov.github.io/data-design-standards/)
